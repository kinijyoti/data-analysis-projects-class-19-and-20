# %% [markdown]
# # Data Visualization with Python Studio
#
# At this point, you should already have connected with the rest of your group to divide up who is going to do what.
#
# Use this notebook to create your visualizations.
#
# Below, we set up the dataframe with the Goodreads dataset for you.
#
# If you run this cell, you may get an error that some lines were skipped. Do not worry about that!
#
# For this studio, we want to focus on creating an effective visualization.

# %%
# Here is the setup of the dataframe. Feel free to use .info() or .head() to 
## get a better understanding of what is inside the dataframe!

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style

df = pd.read_csv("books.csv", on_bad_lines='skip')

years = []

for y in df['publication_date']:
    date = y.split("/")
    years.append(date[2])

df["year"] = years

df.head(200)
# Out:
#      bookID                                              title  \
# 0         1  Harry Potter and the Half-Blood Prince (Harry ...
# 1         2  Harry Potter and the Order of the Phoenix (Har...
# 2         4  Harry Potter and the Chamber of Secrets (Harry...
# 3         5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4         8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ..      ...                                                ...
# 195     446                               The Brooklyn Follies
# 196     447                                        Moon Palace
# 197     453                                The Music of Chance
# 198     454                         Travels in the Scriptorium
# 199     456                                          Leviathan
#
#                         authors  average_rating        isbn         isbn13  \
# 0    J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1    J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                  J.K. Rowling            4.42  0439554896  9780439554893
# 3    J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4    J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
# ..                          ...             ...         ...            ...
# 195                 Paul Auster            3.84  0312426232  9780312426231
# 196                 Paul Auster            3.94  0140115854  9780140115857
# 197                 Paul Auster            3.90  0140154078  9780140154078
# 198                 Paul Auster            3.23  0805081453  9780805081459
# 199                 Paul Auster            3.96  0140178139  9780140178135
#
#     language_code    num_pages  ratings_count  text_reviews_count  \
# 0             eng          652        2095690               27591
# 1             eng          870        2153167               29221
# 2             eng          352           6333                 244
# 3             eng          435        2339585               36325
# 4             eng         2690          41428                 164
# ..            ...          ...            ...                 ...
# 195           eng          306          17977                1157
# 196           eng          320          16099                 503
# 197         en-US          217            361                  36
# 198           eng          145           6688                 562
# 199           eng          275          11744                 443
#
#     publication_date             publisher  year
# 0          9/16/2006       Scholastic Inc.  2006
# 1           9/1/2004       Scholastic Inc.  2004
# 2          11/1/2003            Scholastic  2003
# 3           5/1/2004       Scholastic Inc.  2004
# 4          9/13/2004            Scholastic  2004
# ..               ...                   ...   ...
# 195       10/17/2006               Picador  2006
# 196         4/1/1990         Penguin Books  1990
# 197        12/1/1991         Penguin Books  1991
# 198        1/23/2007  Henry Holt & Company  2007
# 199         9/1/1993         Penguin Books  1993
#
# [200 rows x 13 columns]

# %% [markdown]
# With your dataframe set up, time to start creating visualizations!

# %%
# Use your Python skills to create a visualization here.

average_ratings = df.groupby('title')['average_rating'].mean()
ratings = df['ratings_count'].sum()
text_reviews = df['text_reviews_count'].sum()


playlist = []
playlist.append(ratings)
playlist.append(text_reviews)

keys = []
keys.append('ratings_count')
keys.append('text_reviews_count')

plt.bar(x=keys, height=playlist ,width=.2, color ='maroon')

plt.title("Count of Ratings and Text ")
plt.xlabel("Rating count")
plt.ylabel("Text review count")

print(ratings)
#average_ratings = average_ratings.sort_values(by ='average_rating', ascending=False)
#average_ratings = average_ratings.sort_values(by='average_rating', ascending=False)
#print(average_ratings)
#top_author = average_ratings.iloc[0]
#print(top_author)

# plt.bar(average_ratings['authors'], average_ratings['average_rating'], color='skyblue')
# plt.title('Average Rating per Author')
# plt.xlabel('Author')
# plt.ylabel('Average Rating')
# plt.xticks(rotation=45)
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.show()

# years = df.groupby(["year"]).mean()
# sum_by_year = numpy.sort(df.groupby("year")["ratings_count"].sum())

# # converting to billions to make linechart easier to read
# for i in range(len(sum_by_year)):
# 	sum_by_year[i] = sum_by_year[i]

# plt.plot(years, sum_by_year)
# plt.title("Total Streams By Song Release Year (In Billions)")
# plt.xlabel("Release Year")
# plt.ylabel("Total Streams (in billions)")
# Out:
# 199578299

# %%
# Use your Python skills to create a visualization here.
